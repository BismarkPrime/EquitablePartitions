# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\josep\\OneDrive\\Documents\\Para la Escuela\\Research\\Network Theory\\EquitablePartitions\\Jupyter_notebooks'

# %%
os.chdir('../')

# %%
os.listdir()
# Out:
# ['.git',
#  '.gitignore',
#  'computing_equitable_partitions_of_graphs.pdf',
#  'Data',
#  'ep_finder.py',
#  'geometric_leps.pdf',
#  'graphs.py',
#  'Jupyter_notebooks',
#  'lep_finder.py',
#  'README.md',
#  'testD.py',
#  '__pycache__']

# %%
import testD
from importlib import reload
reload(testD)
import lep_finder

# %%
testD.main()
# Out:
# Finding Coarsest EP...
#  [####################################################################################################] 100%
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-e82ace673f33> in <module>
# ----> 1 testD.main()
#
# ~\OneDrive\Documents\Para la Escuela\Research\Network Theory\EquitablePartitions\testD.py in main(nodes, print_results)
#     156         printWithLabel("COARSEST EQUITABLE PARTITION", '=', ep)
#     157
# --> 158     leps = lep_finder.getLocalEquitablePartitionsFromGraph(ep, G)
#     159
#     160     if print_results:
#
# AttributeError: module 'lep_finder' has no attribute 'getLocalEquitablePartitionsFromGraph'
